# %% [markdown]
# # Score distribution (exploratory)
#
# Visualize predicted vs gold score spreads per query. **Not imported by the package.**

# %%
import sys
sys.path.insert(0, "../src")

import matplotlib.pyplot as plt
import numpy as np

# Load metrics JSON from a training run, e.g. outputs/loss_comparison/listnet_s42/training_metrics.json
metrics_path = "../outputs/loss_comparison/listnet_s42/training_metrics.json"
print("Set metrics_path to your run, then plot score_std / separation_ratio_std over epochs.")
